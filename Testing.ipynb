# %%
import main
# Out:
# ==================================================
#        SMART BMI & HEALTHY ROUTINE ASSISTANT
# ==================================================
# 1. Calculate BMI
# 2. Food Suggestions
# 3. Healthy Daily Routine
# 4. Learn About BMI
# 5. Exit
# Enter your choice:  1
# --- BMI CALCULATOR ---
# Enter weight in kg:  72
# Enter height in cm:  182
# Your BMI is: 21.74
# Category: Usual adult BMI range
# Feedback: Good result
#
# Would you like to see food suggestions?
# Enter yes or no:  yes
# --- FOOD SUGGESTIONS ---
# Suggested balanced meals:
# • Breakfast: Idli with sambar or oats with fruit
# • Lunch: Roti, dal and vegetables
# • Snack: Fruit or roasted chana
# • Dinner: Roti, vegetables and dal
#
# These are general educational suggestions.
#
# ==================================================
#        SMART BMI & HEALTHY ROUTINE ASSISTANT
# ==================================================
# 1. Calculate BMI
# 2. Food Suggestions
# 3. Healthy Daily Routine
# 4. Learn About BMI
# 5. Exit
# Enter your choice:  1
# --- BMI CALCULATOR ---
# Enter weight in kg:  111
# Enter height in cm:  132
# Your BMI is: 63.71
# Category: High BMI range
# Feedback: Needs attention
#
# Would you like to see food suggestions?
# Enter yes or no:  yes
# --- FOOD SUGGESTIONS ---
# Suggested balanced meals:
# • Breakfast: Oats or vegetable poha with fruit
# • Lunch: Dal, roti and plenty of vegetables
# • Snack: Fruit or roasted chana
# • Dinner: Vegetables, roti and dal/paneer
#
# These are general educational suggestions.
#
# ==================================================
#        SMART BMI & HEALTHY ROUTINE ASSISTANT
# ==================================================
# 1. Calculate BMI
# 2. Food Suggestions
# 3. Healthy Daily Routine
# 4. Learn About BMI
# 5. Exit
# Enter your choice:  4
# --- ABOUT BMI ---
#
# BMI stands for Body Mass Index.
#
# BMI is calculated using:
#
# BMI = Weight / Height²
#
# BMI uses height and weight as a general
# screening measure.
#
# It does not give a complete picture of health.
#
# The food and routine suggestions in this
# project are general educational information.
#
# BMI categories can be interpreted differently
# for children and teenagers.
#
#
# ==================================================
#        SMART BMI & HEALTHY ROUTINE ASSISTANT
# ==================================================
# 1. Calculate BMI
# 2. Food Suggestions
# 3. Healthy Daily Routine
# 4. Learn About BMI
# 5. Exit
# Enter your choice:  5
# Thank you for using Smart BMI Assistant!

# %%
# TEST 1: Normal BMI calculation

weight = 60
height = 170

heightMetres = height / 100
bmi = weight / (heightMetres * heightMetres)

print("Weight:", weight, "kg")
print("Height:", height, "cm")
print("BMI:", round(bmi, 2))
# Out:
# Weight: 60 kg
# Height: 170 cm
# BMI: 20.76

# %%
# TEST 2: Lower BMI range

weight = 45
height = 170

heightMetres = height / 100
bmi = weight / (heightMetres * heightMetres)

print("Weight:", weight, "kg")
print("Height:", height, "cm")
print("BMI:", round(bmi, 2))
# Out:
# Weight: 45 kg
# Height: 170 cm
# BMI: 15.57

# %%
# TEST 3: Higher BMI range

weight = 80
height = 170

heightMetres = height / 100
bmi = weight / (heightMetres * heightMetres)

print("Weight:", weight, "kg")
print("Height:", height, "cm")
print("BMI:", round(bmi, 2))
# Out:
# Weight: 80 kg
# Height: 170 cm
# BMI: 27.68

# %%
import importlib
import main

importlib.reload(main)
# Out:
# ==================================================
#        SMART BMI & HEALTHY ROUTINE ASSISTANT
# ==================================================
# 1. Calculate BMI
# 2. Food Suggestions
# 3. Healthy Daily Routine
# 4. Learn About BMI
# 5. Exit
# Enter your choice:  9
# Invalid choice. Please try again.
#
# ==================================================
#        SMART BMI & HEALTHY ROUTINE ASSISTANT
# ==================================================
# 1. Calculate BMI
# 2. Food Suggestions
# 3. Healthy Daily Routine
# 4. Learn About BMI
# 5. Exit
# Enter your choice:  1
# --- BMI CALCULATOR ---
# Enter weight in kg:  abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       1 import importlib
#       2 import main
#       3
# ----> 4 importlib.reload(main)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py:129, in reload(module)
#     127 if spec is None:
#     128     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 129 _bootstrap._exec(spec, module)
#     130 # The module may have replaced itself in sys.modules!
#     131 return sys.modules[name]
#
# File <frozen importlib._bootstrap>:874, in _exec(spec, module)
#     870         finally:
#     871             # Update the order of insertion into sys.modules for module
#     872             # clean-up at shutdown.
#     873             module = sys.modules.pop(spec.name)
# --> 874             sys.modules[spec.name] = module
#     875     return module
#
# File <frozen importlib._bootstrap_external>:759, in _LoaderBasics.exec_module(self, module)
#     755         code = self.get_code(module.__name__)
#     756         if code is None:
#     757             raise ImportError(f'cannot load module {module.__name__!r} when '
#     758                               'get_code() returns None')
# --> 759         _bootstrap._call_with_frames_removed(exec, code, module.__dict__)
#
# File <frozen importlib._bootstrap>:491, in _call_with_frames_removed(f, *args, **kwds)
#     487     Use it instead of a normal call in places where including the importlib
#     488     frames introduces unwanted noise into the traceback (e.g. when executing
#     489     module code)
#     490     """
# --> 491     return f(*args, **kwds)
#
# File E:\College\Vityarthi project\Smart-BMI-Assistant\main.py:55
#      50         else:
#      52             print("\nInvalid choice. Please try again.")
# ---> 55 mainMenu()
#
# File E:\College\Vityarthi project\Smart-BMI-Assistant\main.py:25, in mainMenu()
#      21 choice = input("\nEnter your choice: ")
#      23 if choice == "1":
# ---> 25     category = calculateBMI()
#      27     print("\nWould you like to see food suggestions?")
#      28     answer = input("Enter yes or no: ").lower()
#
# File E:\College\Vityarthi project\Smart-BMI-Assistant\bmi.py:5, in calculateBMI()
#       1 def calculateBMI():
#       3     print("\n--- BMI CALCULATOR ---")
# ----> 5     weight = float(input("Enter weight in kg: "))
#       6     height = float(input("Enter height in cm: "))
#       8     heightMetres = height / 100
#
# ValueError: could not convert string to float: 'abc'

# %%
import importlib
import main
importlib.reload(main)
# Out:
# ==================================================
#        SMART BMI & HEALTHY ROUTINE ASSISTANT
# ==================================================
# 1. Calculate BMI
# 2. Food Suggestions
# 3. Healthy Daily Routine
# 4. Learn About BMI
# 5. Exit
# Enter your choice:  1
# --- BMI CALCULATOR ---
# Enter weight in kg:  abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 import importlib
#       2 import main
# ----> 3 importlib.reload(main)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py:129, in reload(module)
#     127 if spec is None:
#     128     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 129 _bootstrap._exec(spec, module)
#     130 # The module may have replaced itself in sys.modules!
#     131 return sys.modules[name]
#
# File <frozen importlib._bootstrap>:869, in _exec(spec, module)
#     867             spec.loader.load_module(name)
#     868         else:
# --> 869             spec.loader.exec_module(module)
#     870 finally:
#     871     # Update the order of insertion into sys.modules for module
#     872     # clean-up at shutdown.
#     873     module = sys.modules.pop(spec.name)
#
# File <frozen importlib._bootstrap_external>:759, in _LoaderBasics.exec_module(self, module)
#     756 if code is None:
#     757     raise ImportError(f'cannot load module {module.__name__!r} when '
#     758                       'get_code() returns None')
# --> 759 _bootstrap._call_with_frames_removed(exec, code, module.__dict__)
#
# File <frozen importlib._bootstrap>:491, in _call_with_frames_removed(f, *args, **kwds)
#     483 def _call_with_frames_removed(f, *args, **kwds):
#     484     """remove_importlib_frames in import.c will always remove sequences
#     485     of importlib frames that end with a call to this function
#     486
#    (...)    489     module code)
#     490     """
# --> 491     return f(*args, **kwds)
#
# File E:\College\Vityarthi project\Smart-BMI-Assistant\main.py:55
#      50         else:
#      52             print("\nInvalid choice. Please try again.")
# ---> 55 mainMenu()
#
# File E:\College\Vityarthi project\Smart-BMI-Assistant\main.py:25, in mainMenu()
#      21 choice = input("\nEnter your choice: ")
#      23 if choice == "1":
# ---> 25     category = calculateBMI()
#      27     print("\nWould you like to see food suggestions?")
#      28     answer = input("Enter yes or no: ").lower()
#
# File E:\College\Vityarthi project\Smart-BMI-Assistant\bmi.py:5, in calculateBMI()
#       1 def calculateBMI():
#       3     print("\n--- BMI CALCULATOR ---")
# ----> 5     weight = float(input("Enter weight in kg: "))
#       6     height = float(input("Enter height in cm: "))
#       8     heightMetres = height / 100
#
# ValueError: could not convert string to float: 'abc'

# %%
main.mainMenu()
# Out:
# ==================================================
#        SMART BMI & HEALTHY ROUTINE ASSISTANT
# ==================================================
# 1. Calculate BMI
# 2. Food Suggestions
# 3. Healthy Daily Routine
# 4. Learn About BMI
# 5. Exit
# Enter your choice:  1
# --- BMI CALCULATOR ---
# Enter weight in kg:  abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 main.mainMenu()
#
# File E:\College\Vityarthi project\Smart-BMI-Assistant\main.py:25, in mainMenu()
#      21 choice = input("\nEnter your choice: ")
#      23 if choice == "1":
# ---> 25     category = calculateBMI()
#      27     print("\nWould you like to see food suggestions?")
#      28     answer = input("Enter yes or no: ").lower()
#
# File E:\College\Vityarthi project\Smart-BMI-Assistant\bmi.py:5, in calculateBMI()
#       1 def calculateBMI():
#       3     print("\n--- BMI CALCULATOR ---")
# ----> 5     weight = float(input("Enter weight in kg: "))
#       6     height = float(input("Enter height in cm: "))
#       8     heightMetres = height / 100
#
# ValueError: could not convert string to float: 'abc'

# %%
import bmi
print(bmi.__file__)
# Out:
# E:\College\Vityarthi project\Smart-BMI-Assistant\bmi.py

# %%
import main
# Out:
# ==================================================
#        SMART BMI & HEALTHY ROUTINE ASSISTANT
# ==================================================
# 1. Calculate BMI
# 2. Food Suggestions
# 3. Healthy Daily Routine
# 4. Learn About BMI
# 5. Exit
# Enter your choice:  1
# --- BMI CALCULATOR ---
# Enter weight in kg:  abc
# Invalid input. Please enter numbers only.
#
# Would you like to see food suggestions?
